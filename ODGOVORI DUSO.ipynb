# %% [markdown]
# Prashanja so odg:

# %% [markdown]
# 1. (5 поени) Кои алгоритми за пребарување се слепи, и зошто ги нарекуваме слепи?
# - Слепи алгоритми за пребарување се пребарувањата по широчина и длабочина, и пребарување со униформна цена. Се нарекуваат слепи затоа што немаат информации каде треба да пребаруваат, тие почнуваат да пребаруваат според кодот кој им го задаваме, но не знаат каде одат се додека не го најдат тоа што го бараат.

# %% [markdown]
# 2. (5 поени) Зошто избираме да ја користиме библиотеката heapq при имплементирање на алгоритмите за пребарување?
# - Избираме да ја користиме библиотеката heapq затоа што работи многу побрзо, ги преуредува елементите на специјален начин и најбрзо ни враќа решение за даден проблем.

# %% [markdown]
# 3. (15 поени) Дали избраниот алгоритам може да се убрза со користење на пребарување А*? Осмисли функција за дојава, и објасни го начинот на функционирање на твојата функција, и како истата може да го убрза избраниот алгоритам.
# - А* пребарувањето може да го убрза дадениот алгоритам, меѓутоа тоа зависи најмногу од избраната функција за дојава.
# - Pr kako da napises za manhattan zosto go ubrzuva: Go ubrzuva so toa sto mu dava nasoki na kade da se dvizi i go nasocuva pobrzo kon posakuvanata cel.

# %% [markdown]
# # PARAFRAZIRANI:

# %% [markdown]
# 1) Слепите алгоритми за пребарување, како пребарувањето по широчина, по длабочина и со униформна цена, се нарекуваат така бидејќи немаат информации за насоката на пребарувањето. Тие следат инструкции од кодот, но не знаат каде води пребарувањето сè додека не го пронајдат бараното решение.
# 2. Избираме да ја користиме библиотеката heapq бидејќи е значително побрза, ги организира елементите на специфичен начин и најефикасно го враќа решението за поставениот проблем.
#
# 3. А* пребарувањето може да го забрза избраниот алгоритам, но тоа во голема мера зависи од функцијата за дојава што ќе се искористи. На пример, функцијата за дојава базирана на Манхетн растојанието го забрзува процесот така што му дава насоки за движење и го води алгоритмот побрзо кон посакуваната цел.

# %% [markdown]
# # ODGOVORI OD CHATGPT
# ### Прв начин: Компактен и директен стил
#
# **1. Како ќе ја дефинираш состојбата за овој проблем?**
# Состојбата претставува моментална конфигурација на системот, која ги вклучува сите потребни информации за следните чекори. Оваа дефиниција овозможува јасно следење на напредокот кон решението.
#
# **2. Како ќе ја дефинираш почетната и крајната состојба?**
# Почетната состојба е иницијалната поставеност на проблемот, а крајната е целосно решението кое го задоволува поставените услови.
#
# **3. Дали ќе користиш состојба или функција за проверка на целта?**
# Ќе се користи функција за проверка на целта, бидејќи тоа овозможува поголема флексибилност при дефинирањето на критериумите за успех.
#
# **4. Која податочна структура ќе ја користиш за зачувување на состојбата?**
# Приоритетна редица ќе биде избрана поради ефикасното управување со состојбите, овозможувајќи брзо пристапување до најважните елементи.
#
# ---
#
# **5. Како ќе се одвива разгранувањето преку `expand_state()`?**
# Функцијата `expand_state()` генерира нови валидни состојби од тековната состојба, базирани на дозволените транзиции. Вратените состојби се додаваат за понатамошна обработка.
#
# ---
#
# **6. Кои алгоритми за пребарување се слепи и зошто ги нарекуваме слепи?**
# Слепи алгоритми се: пребарување по широчина (BFS), пребарување по длабочина (DFS) и пребарување со униформна цена (UCS). Тие се нарекуваат слепи бидејќи не користат информации за насоката кон целта.
#
# ---
#
# **7. Кој алгоритам за слепо пребарување ќе го користиш и зошто?**
# Пребарувањето со униформна цена (UCS) е избрано поради неговата способност да наоѓа оптимални решенија кај проблеми со различни трошоци на транзиција.
#
#
#
# **9. Зошто избираме да ја користиме `heapq`?**
# `heapq` е брза и ефикасна за работа со приоритетни редици, овозможувајќи оптимизирано додавање и вадење елементи.
#
# ---
#
# **10. Може ли алгоритамот да се убрза со A*?**
# Со користење на A* пребарувањето и функција за дојава како Манхетн растојание, алгоритмот добива насока и побрзо се движи кон целта.
#
# **Примерна имплементација на A*:**
#
#
# ```
#
# ---
#
# ### Втор начин: Опширен и објаснет стил
#
# **1. Како ќе ја дефинираш состојбата за овој проблем?**
# Состојбата ќе биде репрезентација на тековната положба во решението, која ги вклучува сите релевантни информации, како позиција, трошок, и други својства. Овој избор ја олеснува идентификацијата на можните транзиции и ја задржува логиката едноставна за следење.
#
# **2. Како ќе ја дефинираш почетната и крајната состојба?**
# Почетната состојба ја претставува иницијалната конфигурација на проблемот, дефинирана според условите на задачата. Крајната состојба е состојбата која ги исполнува сите услови за завршување на задачата, како што е поставеното целно достигнување.
#
# **3. Дали ќе користиш состојба или функција за проверка на целта?**
# Ќе користам функција за проверка дали целта е постигната. Таа нуди флексибилност, бидејќи овозможува дефинирање на целта без да се складираат сите можни крајни состојби.
#
# **4. Која податочна структура ќе ја користиш за зачувување на состојбата?**
# Најдобра структура за ова е приоритетната редица, бидејќи овозможува ефективно одржување на состојбите сортирани според нивниот приоритет (трошок или функција за дојава).
#
# ---
#
# **5. Како ќе се одвива разгранувањето преку `expand_state()`?**
# Функцијата `expand_state()` ќе креира нови состојби од дадената тековна состојба преку примена на сите валидни транзиции (движења или операции). Овие нови состојби се проверуваат и додаваат во редицата за понатамошно обработување.
#
# ---
#
# **6. Кои алгоритми за пребарување се слепи и зошто ги нарекуваме слепи?**
# Пребарувањето по широчина, длабочина и со униформна цена се слепи алгоритми. Тие не користат никакви дополнителни информации за насочување кон целта, туку систематски ги истражуваат сите можности.
#
# ---
#
# **7. Кој алгоритам за слепо пребарување ќе го користиш и зошто?**
# Алгоритмот со униформна цена е најдобар избор за проблеми каде транзициите имаат различен трошок, бидејќи секогаш пронаоѓа оптимално решение со најнизок збир на трошоци.
#
# ---
#
# **8. Имплементација на UCS:**
# *Истиот код од првиот стил*
#
# ---
#
# **9. Зошто избираме да ја користиме `heapq`?**
# Библиотеката `heapq` ја подобрува брзината и ефикасноста, овозможувајќи брзи операции како вметнување и извлекување на елементот со најмал приоритет.
#
# ---
#
# **10. Може ли алгоритамот да се убрза со A*?**
# Да, функцијата за дојава како Манхетн растојанието додава предвидување за тоа која состојба е поблиску до целта, намалувајќи го бројот на непотребни состојби кои треба да се разгледаат.
#
# *Истиот код за A* од првиот стил.*
